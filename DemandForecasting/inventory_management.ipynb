# %%
import pandas as pd

# %%
dataset = pd.read_csv('file1.csv', delimiter = ',')
dataset.shape
# Out:
# (90, 501)

# %%
dataset
# Out:
#           date  item_10_store_10_sales  item_10_store_1_sales  \
# 0   2017-01-01                      79                     53
# 1   2017-01-02                      55                     51
# 2   2017-01-03                      53                     53
# 3   2017-01-04                      66                     46
# 4   2017-01-05                      64                     46
# 5   2017-01-06                      63                     53
# 6   2017-01-07                      80                     61
# 7   2017-01-08                      84                     64
# 8   2017-01-09                      51                     36
# 9   2017-01-10                      58                     53
# 10  2017-01-11                      54                     44
# 11  2017-01-12                      63                     52
# 12  2017-01-13                      70                     69
# 13  2017-01-14                      62                     69
# ...

# %%
# dropping date
df=dataset.drop(['date'], axis=1)

# %%
df
# Out:
#     item_10_store_10_sales  item_10_store_1_sales  item_10_store_2_sales  \
# 0                       79                     53                     89
# 1                       55                     51                     44
# 2                       53                     53                     52
# 3                       66                     46                     66
# 4                       64                     46                     87
# 5                       63                     53                     73
# 6                       80                     61                     93
# 7                       84                     64                     88
# 8                       51                     36                     51
# 9                       58                     53                     86
# 10                      54                     44                     66
# 11                      63                     52                     70
# ...

# %%
# summing up
sum_df=df.sum(axis = 0, skipna = True)

# %%
sum_df
# Out:
# item_10_store_10_sales    6482
# item_10_store_1_sales     5269
# item_10_store_2_sales     7365
# item_10_store_3_sales     6663
# item_10_store_4_sales     6122
# item_10_store_5_sales     4462
# item_10_store_6_sales     4368
# item_10_store_7_sales     4053
# item_10_store_8_sales     7080
# item_10_store_9_sales     6193
# item_11_store_10_sales    6063
# item_11_store_1_sales     4940
# item_11_store_2_sales     7057
# item_11_store_3_sales     6344
# item_11_store_4_sales     5695
# item_11_store_5_sales     4194
# item_11_store_6_sales     4155
# item_11_store_7_sales     3715
# item_11_store_8_sales     6751
# item_11_store_9_sales     5809
# item_12_store_10_sales    6064
# item_12_store_1_sales     4903
# item_12_store_2_sales     6985
# item_12_store_3_sales     6255
# item_12_store_4_sales     5823
# item_12_store_5_sales     4088
# item_12_store_6_sales     4184
# item_12_store_7_sales     3875
# item_12_store_8_sales     6693
# item_12_store_9_sales     5720
# ...

# %% [markdown]
# sum_df
